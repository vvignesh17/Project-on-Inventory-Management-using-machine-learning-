# %%
import pandas as pd
names =  pd.read_csv("company.csv")
print('The shape: %d x %d' % names.shape)
names.head()
# Out:
# The shape: 663000 x 3
#    Line Number                        Company Name  Company CIK Key
# 0            1                              !J INC          1438823
# 1            2       #1 A LIFESAFER HOLDINGS, INC.          1509607
# 2            3  #1 ARIZONA DISCOUNT PROPERTIES LLC          1457512
# 3            4                   #1 PAINTBALL CORP          1433777
# 4            5                               $ LLC          1427189

# %%
names=names[:10000]

# %%
import re

def ngrams(string, n=4):
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

print('All 3-grams in "McDonalds":')
ngrams('McDonalds')
# Out:
# All 3-grams in "McDonalds":
# ['McDo', 'cDon', 'Dona', 'onal', 'nald', 'alds']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

company_names = names['Company Name']
vectorizer = TfidfVectorizer(min_df=3, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# %%
import numpy as np
from scipy.sparse import csr_matrix
import sparse_dot_topn.sparse_dot_topn as ct

def awesome_cossim_top(A, B, ntop, lower_bound=0):
    # force A and B as a CSR matrix.
    # If they have already been CSR, there is no overhead
    A = A.tocsr()
    B = B.tocsr()
    M, _ = A.shape
    _, N = B.shape
 
    idx_dtype = np.int32
 
    nnz_max = M*ntop
 
    indptr = np.zeros(M+1, dtype=idx_dtype)
    indices = np.zeros(nnz_max, dtype=idx_dtype)
    data = np.zeros(nnz_max, dtype=A.dtype)

    ct.sparse_dot_topn(
        M, N, np.asarray(A.indptr, dtype=idx_dtype),
        np.asarray(A.indices, dtype=idx_dtype),
        A.data,
        np.asarray(B.indptr, dtype=idx_dtype),
        np.asarray(B.indices, dtype=idx_dtype),
        B.data,
        ntop,
        lower_bound,
        indptr, indices, data)

    return csr_matrix((data,indices,indptr),shape=(M,N))

# %%
import time
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 100, 0.75)
t = time.time()-t1
print("SELFTIMED:", t)
# Out:
# SELFTIMED: 0.3454611301422119

# %%
def get_matches_df(sparse_matrix, name_vector, top=100):
    non_zeros = sparse_matrix.nonzero()
    
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    if top:
        nr_matches = top
    else:
        nr_matches = sparsecols.size
    
    left_side = np.empty([nr_matches], dtype=object)
    right_side = np.empty([nr_matches], dtype=object)
    similairity = np.zeros(nr_matches)
    
    for index in range(0, nr_matches):
        left_side[index] = name_vector[sparserows[index]]
        right_side[index] = name_vector[sparsecols[index]]
        similairity[index] = sparse_matrix.data[index]
    
    return pd.DataFrame({'left_side': left_side,
                          'right_side': right_side,
                           'similairity': similairity})

# %%
matches_df = get_matches_df(matches, company_names, top=1000)

matches_df
# Out:
#                                           left_side  \
# 0                                            !J INC
# 1                     #1 A LIFESAFER HOLDINGS, INC.
# 2                #1 ARIZONA DISCOUNT PROPERTIES LLC
# 3                                 #1 PAINTBALL CORP
# 4                                             $ LLC
# 5                                             $ LLC
# 6                                             $ LLC
# 7                                             $ LLC
# 8                               & S MEDIA GROUP LLC
# 9                               & S MEDIA GROUP LLC
# 10                          &TV COMMUNICATIONS INC.
# 11                          &TV COMMUNICATIONS INC.
# 12                          &TV COMMUNICATIONS INC.
# 13                          &TV COMMUNICATIONS INC.
# 14                          &TV COMMUNICATIONS INC.
# 15                          &TV COMMUNICATIONS INC.
# 16                          &TV COMMUNICATIONS INC.
# 17                          &TV COMMUNICATIONS INC.
# 18                                     'MKTG, INC.'
# 19                                 'OHANA LABS INC.
# 20                (OURCROWD INVESTMENT IN MST) L.P.
# 21                               (Y.Z) QUEENCO LTD.
# 22                               .CLUB DOMAINS, LLC
# 23                     012 SMILE.COMMUNICATIONS LTD
# 24                                   02 MEDTECH INC
# 25                                   02 MEDTECH INC
# 26                                        0210, LLC
# 27                                        0210, LLC
# 28                                 024 PHARMA, INC.
# 29                                 024 PHARMA, INC.
# ..                                              ...
# 970                         1230 N OCEAN LENDER LLC
# 971                        1231 K STREET MEMBER LLC
# 972                                       1233 CORP
# 973                    12342RM620 INVESTMENTS, L.P.
# 974                      1236 MEARNS COMMUNITIES LP
# 975                          1236 MEARNS MANAGER LP
# 976                               1239 BAY AREA, LP
# 977  123SIGNUP ASSOCIATION MANAGEMENT SOLUTIONS INC
# 978                   124 BIRCH LANE ASSOCIATES LLC
# 979                  124 HUDSON STREET EQUITIES LLC
# 980                                  1240 CEDAR LLC
# 981                 1248 SOUTH VINEYARD STREET, LLC
# 982                      125 NORTH 18TH STREET, LLC
# 983                           125 PALMER APARTMENTS
# 984             125 W 44 RESTAURANT ASSOCIATES, LLC
# 985                          1250 CENTRAL AVE., LLC
# 986                          1250 HUNTERS COVE, LLC
# 987                        1251 CAPITAL GROUP, INC.
# 988                        1251 CAPITAL GROUP, INC.
# 989                          1255 23RD STREET TRUST
# 990         126-142 MORGAN STREET URBAN RENEWAL LLC
# 991                       1260 AMSTERDAM REALTY LLC
# 992                                 1260 MARTIN LLC
# 993                              1260 RED BUTTE LLC
# 994                         12600 MULHOLLAND DR LLC
# 995                 12655 WEST JEFFERSON OWNER, LLC
# 996                             1266715 ALBERTA INC
# 997                             1266715 ALBERTA INC
# 998                              12697 INVESTCO LLC
# 999                        127 MADISON PARTNERS LLC
#
#                                          right_side  similairity
# 0                                            !J INC     1.000000
# 1                     #1 A LIFESAFER HOLDINGS, INC.     1.000000
# 2                #1 ARIZONA DISCOUNT PROPERTIES LLC     1.000000
# 3                                 #1 PAINTBALL CORP     1.000000
# 4                                          ABJJ LLC     1.000000
# 5                                        3FLOZ, LLC     1.000000
# 6                                        34FMGJ LLC     1.000000
# 7                                             $ LLC     1.000000
# 8                               & S MEDIA GROUP LLC     1.000000
# 9                               2AM MEDIA GROUP LLC     0.764606
# 10                          &TV COMMUNICATIONS INC.     1.000000
# 11                           3DH COMMUNICATIONS INC     0.881299
# 12                        AAROHI COMMUNICATIONS INC     0.847861
# 13                      ACCESS COMMUNICATIONS, INC.     0.807997
# 14                          ACME COMMUNICATIONS INC     0.793584
# 15                      ACRODYNE COMMUNICATIONS INC     0.784943
# 16                      ACACIA COMMUNICATIONS, INC.     0.765824
# 17                          9278 COMMUNICATIONS INC     0.765735
# 18                                     'MKTG, INC.'     1.000000
# 19                                 'OHANA LABS INC.     1.000000
# 20                (OURCROWD INVESTMENT IN MST) L.P.     1.000000
# 21                               (Y.Z) QUEENCO LTD.     1.000000
# 22                               .CLUB DOMAINS, LLC     1.000000
# 23                     012 SMILE.COMMUNICATIONS LTD     1.000000
# 24                                   02 MEDTECH INC     1.000000
# 25                                      4TECH, INC.     0.908172
# 26                                        0210, LLC     1.000000
# 27                                        90210 LLC     0.884526
# 28                                 024 PHARMA, INC.     1.000000
# 29                                    AAIPHARMA INC     0.822611
# ..                                              ...          ...
# 970                         1230 N OCEAN LENDER LLC     1.000000
# 971                        1231 K STREET MEMBER LLC     1.000000
# 972                                       1233 CORP     1.000000
# 973                    12342RM620 INVESTMENTS, L.P.     1.000000
# 974                      1236 MEARNS COMMUNITIES LP     1.000000
# 975                          1236 MEARNS MANAGER LP     1.000000
# 976                               1239 BAY AREA, LP     1.000000
# 977  123SIGNUP ASSOCIATION MANAGEMENT SOLUTIONS INC     1.000000
# 978                   124 BIRCH LANE ASSOCIATES LLC     1.000000
# 979                  124 HUDSON STREET EQUITIES LLC     1.000000
# 980                                  1240 CEDAR LLC     1.000000
# 981                 1248 SOUTH VINEYARD STREET, LLC     1.000000
# 982                      125 NORTH 18TH STREET, LLC     1.000000
# 983                           125 PALMER APARTMENTS     1.000000
# 984             125 W 44 RESTAURANT ASSOCIATES, LLC     1.000000
# 985                          1250 CENTRAL AVE., LLC     1.000000
# 986                          1250 HUNTERS COVE, LLC     1.000000
# 987                        1251 CAPITAL GROUP, INC.     1.000000
# 988                          21 CAPITAL GROUP, INC.     0.857898
# 989                          1255 23RD STREET TRUST     1.000000
# 990         126-142 MORGAN STREET URBAN RENEWAL LLC     1.000000
# 991                       1260 AMSTERDAM REALTY LLC     1.000000
# 992                                 1260 MARTIN LLC     1.000000
# 993                              1260 RED BUTTE LLC     1.000000
# 994                         12600 MULHOLLAND DR LLC     1.000000
# 995                 12655 WEST JEFFERSON OWNER, LLC     1.000000
# 996                             1266715 ALBERTA INC     1.000000
# 997                              961266 ALBERTA INC     0.795508
# 998                              12697 INVESTCO LLC     1.000000
# 999                        127 MADISON PARTNERS LLC     1.000000
#
# [1000 rows x 3 columns]
